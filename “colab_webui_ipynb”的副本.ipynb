# %% [markdown]
# <a href="https://colab.research.google.com/github/lianta258/kutwo/blob/main/%E2%80%9Ccolab_webui_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:52
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5100, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (211/211), done.
# remote: Total 5100 (delta 136), reused 60 (delta 60), pack-reused 4829 (from 3)
# Receiving objects: 100% (5100/5100), 13.21 MiB | 16.88 MiB/s, done.
# Resolving deltas: 100% (2926/2926), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.2.25  |       h06a4308_0         129 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python /content/GPT-SoVITS/GPT_SoVITS/inference_webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# GPT_SoVITS/pretrained_models/s2G488k.pth v2 v2 False
# loading sovits_v1 <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://0699a73dab0878b143.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# GPT_SoVITS/pretrained_models/s2Gv3.pth v2 v3 False
# loading sovits_v3 <All keys matched successfully>
# Actual Input Reference Text: 世尊啊，为啥世人都常说母子之情特别难以割舍呢？佛陀听了，脸上露出温和的微笑。
# Actual Input Target Text: 世尊啊，为啥世人都常说母子之情特别难以割舍呢？佛陀听了，脸上露出温和的微笑
# Actual Input Target Text (after sentence segmentation): 世尊啊，为啥世人都常说母子之情特别难以割舍呢？佛陀听了，脸上露出温和的微笑
# Actual Input Target Text (per sentence): 世尊啊，为啥世人都常说母子之情特别难以割舍呢？佛陀听了，脸上露出温和的微笑。
# Processed text from the frontend (per sentence): 世尊啊,为啥世人都常说母子之情特别难以割舍呢?佛陀听了,脸上露出温和的微笑.
# ...

# %%
# !ls
# Out:
# GPT-SoVITS-WebUI  README.md
